# %%
import pandas as pd

table_2 = pd.read_excel("中国向美国征税_4.4_第二轮.xlsx")
table_1 = pd.read_excel("中国向美国征税_3.23_第一轮.xlsx")

# %%
table_1
# Out:
#       序号      税则号列                                       商品名称     6位码
# 0      1   8011100                                       干的椰子  801110
# 1      2   8011200                                   未去内壳的鲜椰子  801120
# 2      3   8011990                                      其他鲜椰子  801199
# 3      4   8012100                                 鲜或干的未去壳巴西果  801210
# 4      5   8012200                                  鲜或干的去壳巴西果  801220
# 5      6   8013100                                  鲜或干的未去壳腰果  801310
# 6      7   8013200                                   鲜或干的去壳腰果  801320
# 7      8   8021100                                    鲜或干的扁桃核  802110
# 8      9   8021200                                    鲜或干的扁桃仁  802120
# 9     10   8022100                                  鲜或干的未去壳榛子  802210
# 10    11   8022200                                   鲜或干的去壳榛子  802220
# 11    12   8023100                                  鲜或干的未去壳核桃  802310
# ...

# %%
list_6_digits_1 = []
for item in table_1["税则号列"]:
    list_6_digits_1.append(str(item)[0:6])

# %%
list_6_digits_1
# Out:
# ['801110',
#  '801120',
#  '801199',
#  '801210',
#  '801220',
#  '801310',
#  '801320',
#  '802110',
#  '802120',
#  '802210',
#  '802220',
#  '802310',
#  '802320',
#  '802411',
#  '802429',
#  '802510',
#  '802520',
#  '802619',
#  '802620',
#  '802800',
#  '802903',
#  '802909',
#  '803100',
#  '803900',
#  '804100',
#  '804200',
#  '804300',
#  '804400',
#  '804501',
#  '804502',
#  '804503',
#  '805100',
#  '805219',
#  '805220',
#  '805290',
#  '805400',
#  '805500',
#  '805900',
#  '806100',
#  '806200',
#  '807110',
#  '807191',
#  '807200',
#  '808100',
#  '808301',
#  '808309',
#  '809210',
#  '809290',
#  '809300',
#  '809400',
#  '810100',
#  '810200',
#  '810400',
#  '810500',
#  '810600',
#  '810700',
#  '810901',
#  '810903',
#  '810904',
#  '810905',
#  '810906',
#  '810907',
#  '810908',
#  '810909',
#  '811100',
#  '811200',
#  '811909',
#  '812100',
#  '812900',
#  '813100',
#  '813200',
#  '813300',
#  '813401',
#  '813402',
#  '813403',
#  '813404',
# ...

# %%
list_6_digits_2 = []
for item in table_2["税则号列"]:
    list_6_digits_2.append(str(item)[0:6])

# %%
pd.DataFrame(list_6_digits_2).to_excel("b.xlsx")

# %%
pd.DataFrame(list_6_digits_1).to_excel("a.xlsx")
